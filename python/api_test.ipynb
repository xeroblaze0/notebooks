// %%
const url = "https://api.ods.od.nih.gov/dsld/v9/label/82118"

fetch(url)
    // .then( res => res.json())
    .then( data => console.log(data));
// Out:
// Promise { <pending> }
// Response {
//   body: ReadableStream { locked: false },
//   bodyUsed: false,
//   headers: Headers {
//     age: "0",
//     "cache-control": "no-cache, no-store",
//     "content-type": "text/plain; charset=utf-8",
//     date: "Sun, 23 Mar 2025 20:39:31 GMT",
//     "strict-transport-security": "max-age=31536000, max-age=31536000; preload",
//     vary: "Accept-Encoding, Accept-Encoding",
//     via: "https/1.1 api-umbrella (ApacheTrafficServer [cMsSf ])",
//     "x-api-umbrella-request-id": "cloitmkbqsmapb43hkn0",
//     "x-cache": "MISS",
//     "x-cf-routererror": "unknown_route",
//     "x-content-type-options": "nosniff",
//     "x-frame-options": "DENY",
//     "x-vcap-request-id": "d32d07b2-9eff-4408-7272-14208747712c",
//     "x-xss-protection": "1; mode=block"
//   },
//   ok: false,
//   redirected: false,
//   status: 404,
//   statusText: "Not Found",
//   url: "https://api.ods.od.nih.gov/dsld/v9/label/82118"
// }

// %%
const url = "https://api.datalake.sante.service.ec.europa.eu/food-flavourings/food_flavouring_list?format=json&api-version=v1.0"

fetch(url)
    .then( res => res.json())
    .then ( data => console.log(data));
// Out:
// Promise { <pending> }
// {
//   value: [
//     {
//       policy_item_id: 367134,
//       policy_item_code: "POL-FFL-IMPORT-3388",
//       food_flavouring_name: "Limonene"
//     },
//     {
//       policy_item_id: 367180,
//       policy_item_code: "POL-FFL-IMPORT-3389",
//       food_flavouring_name: "1-Isopropyl-4-methylbenzene"
//     },
//     {
//       policy_item_id: 367226,
//       policy_item_code: "POL-FFL-IMPORT-3390",
//       food_flavouring_name: "Pin-2(10)-ene"
//     },
//     {
//       policy_item_id: 367276,
//       policy_item_code: "POL-FFL-IMPORT-3391",
//       food_flavouring_name: "Pin-2(3)-ene"
//     },
//     {
//       policy_item_id: 367326,
//       policy_item_code: "POL-FFL-IMPORT-3392",
//       food_flavouring_name: "Terpinolene"
//     },
//     {
//       policy_item_id: 367372,
//       policy_item_code: "POL-FFL-IMPORT-3393",
//       food_flavouring_name: "alpha-Phellandrene"
//     },
//     {
//       policy_item_id: 367424,
// ...

// %%
const url = "https://api.datalake.sante.service.ec.europa.eu/food-flavourings/food_flavouring_details"

const api_format = "?format=json"
const policy_item_code = "&policy_item_code=POL-FAD-IMPORT-312"
const policy_item_id = "&policy_item_id=180882"
const food_flavouring_name = "&food_flavouring_name=Dodecane"
const api_ver = "&api-version=v1.0"

let site = url+api_format+food_flavouring_name+api_ver

console.log(site);

fetch(site)
    .then( res => res.json())
    .then ( data => console.log(data));
// Out:
// https://api.datalake.sante.service.ec.europa.eu/food-flavourings/food_flavouring_details?format=json&food_flavouring_name=Dodecane&api-version=v1.0
// Promise { <pending> }
// {
//   value: [
//     {
//       policy_item_id: 368332,
//       policy_item_code: "POL-FFL-IMPORT-3413",
//       food_flavouring_name: "Dodecane",
//       fip_url: "https://ec.europa.eu/food/food-feed-portal/screen/food-flavourings/search/details/POL-FFL-IMPORT-3413",
//       food_flavouring_message: null,
//       display_order: 0,
//       food_category_level: "0",
//       food_category: "All categories of flavoured foods",
//       food_category_desc: null,
//       restriction_type: null,
//       restriction_value: null,
//       restriction_unit: null,
//       restriction_comment: null,
//       restriction_note: null,
// ...
