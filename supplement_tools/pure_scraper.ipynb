# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.firefox.service import Service
from selenium.webdriver.firefox.options import Options
import time
import pandas as pd
import sqlite3

service = Service()
options = Options()
options.headless = True
driver = webdriver.Firefox(service=service, options=options)

data = []
BASE_URL = 'https://purebulk.com'

EXCLUDE_WORDS = [
    'Bags',
    'Bottle',
    'Capsule',
    'Capsules',
    'Clif',
    'COA',
    'Dioxide',
    'Hoodia',
    'HPMC',
    'Machine',
    'MCC',
    'Menthol',
    'Oil',
    'Pack',
    'Performance',
    'Picolinate',
    'Pills',
    'PureBulk',
    'Scale',
    'Set',
    'Signature',
    'Softgels',
    'Spoon',
    'Stack',
    'Tasty',
]

interested_headers = [
    "Serving Size",
    "Other Ingredients",
    "Allergen Information",
    "Free of",
    "Suggested Use",
    "Directions",
    "Warning"
]

def close_popup_if_present(driver):
    try:
        close_btn = driver.find_element(By.CSS_SELECTOR, 'button[aria-label="Close dialog"]')
        driver.execute_script("arguments[0].click();", close_btn)
        print("Popup closed.")
        time.sleep(1)  # Give time for popup to close
        return True
    except:
        return False

driver.get('https://purebulk.com/pages/all-products-a-to-z')
time.sleep(2)  # Wait for page to load

# Find the main list
az_list = driver.find_element(By.CLASS_NAME, 'a-to-z-list')
letter_lis = az_list.find_elements(By.CSS_SELECTOR, 'li.letter')

for letter_li in letter_lis:
    header_id = letter_li.get_attribute('id')
    # Find the next sibling ul (the product list)
    sibling = letter_li.find_element(By.XPATH, 'following-sibling::*[1]')
    if sibling.tag_name == 'ul' and 'a-to-z-letter-column' in sibling.get_attribute('class'):
        product_lis = sibling.find_elements(By.CSS_SELECTOR, 'li.product')
        for prod_li in product_lis:
            a_tag = prod_li.find_element(By.TAG_NAME, 'a')
            href = a_tag.get_attribute('href')
            if href.startswith('/'):
                href = BASE_URL + href
            # Get the full link text
            full_text = a_tag.text.strip()
            # Remove price span text if present
            try:
                price_span = a_tag.find_element(By.CLASS_NAME, 'price')
                price_text = price_span.text.strip()
                product_name = full_text.replace(price_text, '').strip()
            except:
                product_name = full_text
            if product_name and href and all(x.lower() not in product_name.lower() for x in EXCLUDE_WORDS):
                data.append({
                    'title': product_name,
                    'url': href,
                    'header_id': header_id,
                })

 # Open database connection and create table before the loop
db_filename = '/home/user/Projects/supplement_tools/purebulk_products.db'
conn = sqlite3.connect(db_filename)
c = conn.cursor()

# Create table ONCE before the loop
c.execute("""
CREATE TABLE IF NOT EXISTS products (
    title TEXT,
    url TEXT UNIQUE,
    header_id TEXT,
    serving_size TEXT,
    other_ingredients TEXT,
    allergen_information TEXT,
    free_of TEXT,
    suggested_use TEXT,
    directions TEXT,
    warning TEXT,
    pricing TEXT
    )
""")

for idx, item in enumerate(data[:5]):
    start_time = time.time()  # Start timer
    url = item['url']
    title = item['title']
    # print(f"Scraping: {title}")
    driver.get(url)
    time.sleep(2)

    # Select the "Bags" option if available, instead of Capsules
    try:
        # Find the label with data-parent="Bags"
        bags_label = driver.find_element(By.CSS_SELECTOR, 'label[data-parent="Bags"]')
        # Find the associated input (usually by 'for' attribute)
        input_id = bags_label.get_attribute('for')
        bags_input = driver.find_element(By.ID, input_id)
        # Select it if not already selected
        if not bags_input.is_selected():
            driver.execute_script("arguments[0].click();", bags_input)
    except Exception as e:
        print(f'Bags option not found or could not be selected for {url}: {e}')


    # Extract Supplemtnent Facts

    supplement_facts = {}

    for header in interested_headers:
        try:
            span = driver.find_element(By.XPATH, f'//span[contains(text(), "{header}")]')
            if header == "Serving Size":
                value = span.text.replace(header, '').strip()
            else:
                parent_p = span.find_element(By.XPATH, './..')
                full_text = parent_p.text.strip()
                value = full_text.replace(header, '').strip()
            supplement_facts[header] = value
            print(f"Found {header}: {value}")
        except Exception as e:
            supplement_facts[header] = None  # or ""

    data[idx].update(supplement_facts)
    # Now supplement_facts contains header: value pairs
    print()
    # Add to your entry
    # data[idx].update(supplement_facts)

     # Extract all size and pricing options from fieldset[data-handle="size"]
    variations = []

    try:
        size_fieldset = driver.find_element(By.CSS_SELECTOR, 'fieldset[data-handle="size"]')
        size_buttons = size_fieldset.find_elements(By.CSS_SELECTOR, 'input[type="radio"][data-value]')
        for btn in size_buttons:
            # sizes.append(btn.get_attribute('data-value'))

            # check and close any popup that may appear
            close_popup_if_present(driver)
            # Select each size button
            driver.execute_script("arguments[0].click();", btn)
            time.sleep(1)
            close_popup_if_present(driver)
            
            # Find and select the "onetime" purchase option
            try:
                onetime_radio = driver.find_element(By.CSS_SELECTOR, 'input[type="radio"][name="purchaseOption"][value="onetime"]')
                if not onetime_radio.is_selected():
                    driver.execute_script("arguments[0].click();", onetime_radio)
                # Extract the following span for the price
                label = onetime_radio.find_element(By.XPATH, './following-sibling::span')
                price_text = label.text.strip()
            except Exception as e:
                print(f"One-time purchase option not found for {url} (size {btn.get_attribute('data-value')}): {e}")
            variations.append({'size': btn.get_attribute('data-value'), 'price': price_text})

        data[idx].update({'Pricing': variations})
        print(f"Scraped: {title} (Time: {(time.time() - start_time):.2f} seconds)")

    except Exception as e:
        print(f"Error extracting prices for {url}: {e}")


   

    # Insert/update after each product
    c.execute("""
    INSERT INTO products (title, url, header_id, serving_size, other_ingredients, allergen_information, free_of, suggested_use, directions, warning, pricing)
    VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
    ON CONFLICT(url) DO UPDATE SET
        title=excluded.title,
        header_id=excluded.header_id,
        serving_size=excluded.serving_size,
        other_ingredients=excluded.other_ingredients,
        allergen_information=excluded.allergen_information,
        free_of=excluded.free_of,
        suggested_use=excluded.suggested_use,
        directions=excluded.directions,
        warning=excluded.warning,
        pricing=excluded.pricing
    """, (
        item.get('title'),
        item.get('url'),
        item.get('header_id'),
        item.get('Serving Size'),
        item.get('Other Ingredients'),
        item.get('Allergen Information'),
        item.get('Free of'),
        item.get('Suggested Use'),
        item.get('Directions'),
        item.get('Warning'),
        str(item.get('Pricing'))
    ))
    conn.commit()  # Commit after each insert/update

    print(f"Scraped: {title} (Time: {(time.time() - start_time):.2f} seconds)")

    # ...existing code...
    # conn.close()

    # print(f"Scraped: {title} (Time: {(time.time() - start_time):.2f} seconds)")
    # print("Title: ", title)
    # print("Entry:", entry)
    # print("Variations:", variations)
    # print()

conn.close()
driver.quit()

print(f"\nSuccessfully saved {len(data)} products to {db_filename}")

# %%
import sqlite3
import json
import ast

db_filename = '/home/user/Projects/supplement_tools/purebulk_products.db'
conn = sqlite3.connect(db_filename)
c = conn.cursor()

# Select all rows
c.execute("SELECT url, pricing FROM products")
rows = c.fetchall()

for url, pricing in rows:
    print(f"Raw pricing for {url}: {pricing}")
    try:
        # Convert Python literal string to Python object
        prices = ast.literal_eval(pricing)
        # print(f"Loaded pricing for {url}: {prices}")
        for entry in prices:
            entry['price'] = entry['price'].replace("One-time purchase ", "")
        # print(f"Cleaned pricing for {url}: {prices}")
        # If you want to convert to JSON string for future use:
        pricing_json = json.dumps(prices)
        print(f"Cleaned pricing JSON for {url}: {pricing_json}")
        c.execute("UPDATE products SET pricing = ? WHERE url = ?", (json.dumps(prices), url))
    except Exception as e:
        print(f"Error loading pricing for {url}: {e}")

conn.commit()
conn.close()
# Out:
# Raw pricing for https://purebulk.com/products/5-htp-powder: [{'size': '10 grams', 'price': 'One-time purchase $6.25'}, {'size': '25 grams', 'price': 'One-time purchase $13.50'}, {'size': '50 grams', 'price': 'One-time purchase $24.50'}, {'size': '100 grams', 'price': 'One-time purchase $44.25'}, {'size': '250 grams', 'price': 'One-time purchase $94.50'}, {'size': '500 grams', 'price': 'One-time purchase $170.95'}, {'size': '1 kilogram', 'price': 'One-time purchase $307.95'}, {'size': '300ct 150mg Gel. Caps.', 'price': 'One-time purchase $307.95'}, {'size': '300ct 150mg Veg. Caps.', 'price': 'One-time purchase $307.95'}]
# Cleaned pricing JSON for https://purebulk.com/products/5-htp-powder: [{"size": "10 grams", "price": "$6.25"}, {"size": "25 grams", "price": "$13.50"}, {"size": "50 grams", "price": "$24.50"}, {"size": "100 grams", "price": "$44.25"}, {"size": "250 grams", "price": "$94.50"}, {"size": "500 grams", "price": "$170.95"}, {"size": "1 kilogram", "price": "$307.95"}, {"size": "300ct 150mg Gel. Caps.", "price": "$307.95"}, {"size": "300ct 150mg Veg. Caps.", "price": "$307.95"}]
# Raw pricing for https://purebulk.com/products/acai-berry: [{'size': '50 grams', 'price': 'One-time purchase $8.25'}, {'size': '100 grams', 'price': 'One-time purchase $14.95'}, {'size': '250 grams', 'price': 'One-time purchase $32.25'}, {'size': '1 kilogram', 'price': 'One-time purchase $105.95'}, {'size': '120ct 600mg Veg. Caps.', 'price': 'One-time purchase $105.95'}, {'size': '120ct 600mg Gel. Caps.', 'price': 'One-time purchase $105.95'}]
# Cleaned pricing JSON for https://purebulk.com/products/acai-berry: [{"size": "50 grams", "price": "$8.25"}, {"size": "100 grams", "price": "$14.95"}, {"size": "250 grams", "price": "$32.25"}, {"size": "1 kilogram", "price": "$105.95"}, {"size": "120ct 600mg Veg. Caps.", "price": "$105.95"}, {"size": "120ct 600mg Gel. Caps.", "price": "$105.95"}]
# Raw pricing for https://purebulk.com/products/acerola-cherry: [{'size': '50 grams', 'price': 'One-time purchase $5.25'}, {'size': '100 grams', 'price': 'One-time purchase $9.50'}, {'size': '250 grams', 'price': 'One-time purchase $20.50'}, {'size': '500 grams', 'price': 'One-time purchase $36.95'}, {'size': '1 kilogram', 'price': 'One-time purchase $66.95'}, {'size': '120ct 600mg Veg. Caps', 'price': 'One-time purchase $66.95'}, {'size': '120ct 600mg Gel. Caps', 'price': 'One-time purchase $66.95'}]
# Cleaned pricing JSON for https://purebulk.com/products/acerola-cherry: [{"size": "50 grams", "price": "$5.25"}, {"size": "100 grams", "price": "$9.50"}, {"size": "250 grams", "price": "$20.50"}, {"size": "500 grams", "price": "$36.95"}, {"size": "1 kilogram", "price": "$66.95"}, {"size": "120ct 600mg Veg. Caps", "price": "$66.95"}, {"size": "120ct 600mg Gel. Caps", "price": "$66.95"}]
# Raw pricing for https://purebulk.com/products/acid-succinate-vitamin-e: [{'size': '25 grams', 'price': 'One-time purchase $9.95'}, {'size': '50 grams', 'price': 'One-time purchase $17.95'}, {'size': '100 grams', 'price': 'One-time purchase $32.50'}, {'size': '250 grams', 'price': 'One-time purchase $69.50'}, {'size': '500 grams', 'price': 'One-time purchase $125.95'}, {'size': '1 kilogram', 'price': 'One-time purchase $226.95'}]
# Cleaned pricing JSON for https://purebulk.com/products/acid-succinate-vitamin-e: [{"size": "25 grams", "price": "$9.95"}, {"size": "50 grams", "price": "$17.95"}, {"size": "100 grams", "price": "$32.50"}, {"size": "250 grams", "price": "$69.50"}, {"size": "500 grams", "price": "$125.95"}, {"size": "1 kilogram", "price": "$226.95"}]
# Raw pricing for https://purebulk.com/products/african-mango-extract: [{'size': '50 grams', 'price': 'One-time purchase $4.25'}, {'size': '100 grams', 'price': 'One-time purchase $7.75'}, {'size': '250 grams', 'price': 'One-time purchase $16.75'}, {'size': '500 grams', 'price': 'One-time purchase $30.25'}, {'size': '1 kilogram', 'price': 'One-time purchase $54.50'}, {'size': '120ct 500mg Veg. Caps.', 'price': 'One-time purchase $54.50'}, {'size': '300ct 500mg Gel. Caps.', 'price': 'One-time purchase $54.50'}, {'size': '300ct 500mg Veg. Caps.', 'price': 'One-time purchase $54.50'}]
# Cleaned pricing JSON for https://purebulk.com/products/african-mango-extract: [{"size": "50 grams", "price": "$4.25"}, {"size": "100 grams", "price": "$7.75"}, {"size": "250 grams", "price": "$16.75"}, {"size": "500 grams", "price": "$30.25"}, {"size": "1 kilogram", "price": "$54.50"}, {"size": "120ct 500mg Veg. Caps.", "price": "$54.50"}, {"size": "300ct 500mg Gel. Caps.", "price": "$54.50"}, {"size": "300ct 500mg Veg. Caps.", "price": "$54.50"}]
# Raw pricing for https://purebulk.com/products/agmatine-sulfate: None
# Error loading pricing for https://purebulk.com/products/agmatine-sulfate: 'NoneType' object is not iterable
# Raw pricing for https://purebulk.com/products/alcar-acetyl-l-carnitine: [{'size': '50 grams', 'price': 'One-time purchase $7.25'}, {'size': '100 grams', 'price': 'One-time purchase $13.25'}, {'size': '250 grams', 'price': 'One-time purchase $28.50'}, {'size': '500 grams', 'price': 'One-time purchase $51.50'}, {'size': '1 kilogram', 'price': 'One-time purchase $92.95'}, {'size': '1.5 kilograms', 'price': 'One-time purchase $132.95'}, {'size': '120ct 600mg Veg. Caps.', 'price': 'One-time purchase $132.95'}, {'size': '120ct 600mg Gel. Caps.', 'price': 'One-time purchase $132.95'}]
# Cleaned pricing JSON for https://purebulk.com/products/alcar-acetyl-l-carnitine: [{"size": "50 grams", "price": "$7.25"}, {"size": "100 grams", "price": "$13.25"}, {"size": "250 grams", "price": "$28.50"}, {"size": "500 grams", "price": "$51.50"}, {"size": "1 kilogram", "price": "$92.95"}, {"size": "1.5 kilograms", "price": "$132.95"}, {"size": "120ct 600mg Veg. Caps.", "price": "$132.95"}, {"size": "120ct 600mg Gel. Caps.", "price": "$132.95"}]
# Raw pricing for https://purebulk.com/products/alcar-ala-powder: [{'size': '50 grams', 'price': 'One-time purchase $9.25'}, {'size': '100 grams', 'price': 'One-time purchase $16.75'}, {'size': '250 grams', 'price': 'One-time purchase $35.95'}, {'size': '500 grams', 'price': 'One-time purchase $64.95'}, {'size': '1 kilogram', 'price': 'One-time purchase $116.95'}, {'size': '120ct 700mg Veg. Caps.', 'price': 'One-time purchase $116.95'}, {'size': '120ct 700mg Gel. Caps.', 'price': 'One-time purchase $116.95'}]
# Cleaned pricing JSON for https://purebulk.com/products/alcar-ala-powder: [{"size": "50 grams", "price": "$9.25"}, {"size": "100 grams", "price": "$16.75"}, {"size": "250 grams", "price": "$35.95"}, {"size": "500 grams", "price": "$64.95"}, {"size": "1 kilogram", "price": "$116.95"}, {"size": "120ct 700mg Veg. Caps.", "price": "$116.95"}, {"size": "120ct 700mg Gel. Caps.", "price": "$116.95"}]
# Raw pricing for https://purebulk.com/products/allulose: [{'size': '250 grams', 'price': 'One-time purchase $11.50'}, {'size': '1 kilogram', 'price': 'One-time purchase $37.50'}]
# Cleaned pricing JSON for https://purebulk.com/products/allulose: [{"size": "250 grams", "price": "$11.50"}, {"size": "1 kilogram", "price": "$37.50"}]
# Raw pricing for https://purebulk.com/products/alpha-gpc-pure: [{'size': '10 grams', 'price': 'One-time purchase $6.50'}, {'size': '25 grams', 'price': 'One-time purchase $14.50'}, {'size': '50 grams', 'price': 'One-time purchase $25.25'}, {'size': '100 grams', 'price': 'One-time purchase $45.50'}, {'size': '250 grams', 'price': 'One-time purchase $97.50'}, {'size': '500 grams', 'price': 'One-time purchase $176.00'}, {'size': '1 kilogram', 'price': 'One-time purchase $318.50'}, {'size': '1.5 kilograms', 'price': 'One-time purchase $454.00'}, {'size': '300ct 300mg Veg. Caps.', 'price': 'One-time purchase $454.00'}, {'size': '300ct 300mg Gel. Caps.', 'price': 'One-time purchase $454.00'}]
# Cleaned pricing JSON for https://purebulk.com/products/alpha-gpc-pure: [{"size": "10 grams", "price": "$6.50"}, {"size": "25 grams", "price": "$14.50"}, {"size": "50 grams", "price": "$25.25"}, {"size": "100 grams", "price": "$45.50"}, {"size": "250 grams", "price": "$97.50"}, {"size": "500 grams", "price": "$176.00"}, {"size": "1 kilogram", "price": "$318.50"}, {"size": "1.5 kilograms", "price": "$454.00"}, {"size": "300ct 300mg Veg. Caps.", "price": "$454.00"}, {"size": "300ct 300mg Gel. Caps.", "price": "$454.00"}]
# Raw pricing for https://purebulk.com/products/alpha-lipoic-acid-r-ala-thioctic-acid: [{'size': '10 grams', 'price': 'One-time purchase $11.25'}, {'size': '25 grams', 'price': 'One-time purchase $24.25'}, {'size': '50 grams', 'price': 'One-time purchase $43.75'}, {'size': '100 grams', 'price': 'One-time purchase $78.95'}, {'size': '250 grams', 'price': 'One-time purchase $168.95'}, {'size': '500 grams', 'price': 'One-time purchase $305.95'}, {'size': '1 kilogram', 'price': 'One-time purchase $554.95'}, {'size': '120ct 200mg Gel. Caps.', 'price': 'One-time purchase $554.95'}, {'size': '120ct 200mg Veg. Caps.', 'price': 'One-time purchase $554.95'}]
# Cleaned pricing JSON for https://purebulk.com/products/alpha-lipoic-acid-r-ala-thioctic-acid: [{"size": "10 grams", "price": "$11.25"}, {"size": "25 grams", "price": "$24.25"}, {"size": "50 grams", "price": "$43.75"}, {"size": "100 grams", "price": "$78.95"}, {"size": "250 grams", "price": "$168.95"}, {"size": "500 grams", "price": "$305.95"}, {"size": "1 kilogram", "price": "$554.95"}, {"size": "120ct 200mg Gel. Caps.", "price": "$554.95"}, {"size": "120ct 200mg Veg. Caps.", "price": "$554.95"}]
# Raw pricing for https://purebulk.com/products/alpha-lipoic-acid-rs-ala-thioctic-acid: [{'size': '25 grams', 'price': 'One-time purchase $6.25'}, {'size': '50 grams', 'price': 'One-time purchase $11.25'}, {'size': '100 grams', 'price': 'One-time purchase $20.25'}, {'size': '250 grams', 'price': 'One-time purchase $43.25'}, {'size': '500 grams', 'price': 'One-time purchase $77.95'}, {'size': '1 kilogram', 'price': 'One-time purchase $140.95'}, {'size': '120ct 550mg Gel. Caps.', 'price': 'One-time purchase $140.95'}, {'size': '120ct 550mg Veg. Caps.', 'price': 'One-time purchase $140.95'}]
# Cleaned pricing JSON for https://purebulk.com/products/alpha-lipoic-acid-rs-ala-thioctic-acid: [{"size": "25 grams", "price": "$6.25"}, {"size": "50 grams", "price": "$11.25"}, {"size": "100 grams", "price": "$20.25"}, {"size": "250 grams", "price": "$43.25"}, {"size": "500 grams", "price": "$77.95"}, {"size": "1 kilogram", "price": "$140.95"}, {"size": "120ct 550mg Gel. Caps.", "price": "$140.95"}, {"size": "120ct 550mg Veg. Caps.", "price": "$140.95"}]
# Raw pricing for https://purebulk.com/products/apple-cider-vinegar: [{'size': '100 grams', 'price': 'One-time purchase $6.50'}, {'size': '250 grams', 'price': 'One-time purchase $13.95'}, {'size': '500 grams', 'price': 'One-time purchase $25.25'}, {'size': '1 kilogram', 'price': 'One-time purchase $45.50'}, {'size': '300ct 400mg Gel. Caps.', 'price': 'One-time purchase $45.50'}, {'size': '300ct 400mg Veg. Caps.', 'price': 'One-time purchase $45.50'}]
# Cleaned pricing JSON for https://purebulk.com/products/apple-cider-vinegar: [{"size": "100 grams", "price": "$6.50"}, {"size": "250 grams", "price": "$13.95"}, {"size": "500 grams", "price": "$25.25"}, {"size": "1 kilogram", "price": "$45.50"}, {"size": "300ct 400mg Gel. Caps.", "price": "$45.50"}, {"size": "300ct 400mg Veg. Caps.", "price": "$45.50"}]
# Raw pricing for https://purebulk.com/products/ascorbic-acid-vitamin-c: [{'size': '100 grams', 'price': 'One-time purchase $6.50'}, {'size': '250 grams', 'price': 'One-time purchase $9.95'}, {'size': '500 grams', 'price': 'One-time purchase $14.95'}, {'size': '1 kilogram', 'price': 'One-time purchase $26.95'}, {'size': '1.5 kilograms', 'price': 'One-time purchase $38.50'}, {'size': '240ct 500mg Veg. Caps.', 'price': 'One-time purchase $38.50'}, {'size': '240ct 500mg Gel. Caps.', 'price': 'One-time purchase $38.50'}]
# Cleaned pricing JSON for https://purebulk.com/products/ascorbic-acid-vitamin-c: [{"size": "100 grams", "price": "$6.50"}, {"size": "250 grams", "price": "$9.95"}, {"size": "500 grams", "price": "$14.95"}, {"size": "1 kilogram", "price": "$26.95"}, {"size": "1.5 kilograms", "price": "$38.50"}, {"size": "240ct 500mg Veg. Caps.", "price": "$38.50"}, {"size": "240ct 500mg Gel. Caps.", "price": "$38.50"}]
# Raw pricing for https://purebulk.com/products/ascorbyl-palmitate-vitamin-c-ester: [{'size': '100 grams', 'price': 'One-time purchase $11.50'}, {'size': '250 grams', 'price': 'One-time purchase $24.75'}, {'size': '500 grams', 'price': 'One-time purchase $44.75'}, {'size': '750 grams', 'price': 'One-time purchase $63.95'}, {'size': '120ct 450mg Veg. Caps.', 'price': 'One-time purchase $63.95'}, {'size': '120ct 450mg Gel. Caps.', 'price': 'One-time purchase $63.95'}]
# Cleaned pricing JSON for https://purebulk.com/products/ascorbyl-palmitate-vitamin-c-ester: [{"size": "100 grams", "price": "$11.50"}, {"size": "250 grams", "price": "$24.75"}, {"size": "500 grams", "price": "$44.75"}, {"size": "750 grams", "price": "$63.95"}, {"size": "120ct 450mg Veg. Caps.", "price": "$63.95"}, {"size": "120ct 450mg Gel. Caps.", "price": "$63.95"}]
# Raw pricing for https://purebulk.com/products/ashwagandha-root-5-withanolides: [{'size': '25 grams', 'price': 'One-time purchase $4.75'}, {'size': '50 grams', 'price': 'One-time purchase $8.75'}, {'size': '100 grams', 'price': 'One-time purchase $15.75'}, {'size': '250 grams', 'price': 'One-time purchase $33.75'}, {'size': '500 grams', 'price': 'One-time purchase $60.95'}, {'size': '1 kilogram', 'price': 'One-time purchase $109.95'}, {'size': '120ct 500mg Gel. Caps.', 'price': 'One-time purchase $109.95'}, {'size': '120ct 500mg Veg. Caps.', 'price': 'One-time purchase $109.95'}, {'size': '300ct 500mg Gel. Caps.', 'price': 'One-time purchase $109.95'}, {'size': '300ct 500mg Veg. Caps.', 'price': 'One-time purchase $109.95'}]
# Cleaned pricing JSON for https://purebulk.com/products/ashwagandha-root-5-withanolides: [{"size": "25 grams", "price": "$4.75"}, {"size": "50 grams", "price": "$8.75"}, {"size": "100 grams", "price": "$15.75"}, {"size": "250 grams", "price": "$33.75"}, {"size": "500 grams", "price": "$60.95"}, {"size": "1 kilogram", "price": "$109.95"}, {"size": "120ct 500mg Gel. Caps.", "price": "$109.95"}, {"size": "120ct 500mg Veg. Caps.", "price": "$109.95"}, {"size": "300ct 500mg Gel. Caps.", "price": "$109.95"}, {"size": "300ct 500mg Veg. Caps.", "price": "$109.95"}]
# Raw pricing for https://purebulk.com/products/beet-root-betanin-12: [{'size': '25 grams', 'price': 'One-time purchase $19.80'}, {'size': '50 grams', 'price': 'One-time purchase $35.75'}, {'size': '100 grams', 'price': 'One-time purchase $64.35'}, {'size': '250 grams', 'price': 'One-time purchase $137.50'}, {'size': '500 grams', 'price': 'One-time purchase $247.50'}, {'size': '120ct 250mg Veg. Caps.', 'price': 'One-time purchase $247.50'}, {'size': '120ct 250mg Gel. Caps.', 'price': 'One-time purchase $247.50'}]
# Cleaned pricing JSON for https://purebulk.com/products/beet-root-betanin-12: [{"size": "25 grams", "price": "$19.80"}, {"size": "50 grams", "price": "$35.75"}, {"size": "100 grams", "price": "$64.35"}, {"size": "250 grams", "price": "$137.50"}, {"size": "500 grams", "price": "$247.50"}, {"size": "120ct 250mg Veg. Caps.", "price": "$247.50"}, {"size": "120ct 250mg Gel. Caps.", "price": "$247.50"}]
# Raw pricing for https://purebulk.com/products/benfotiamine: [{'size': '50 grams', 'price': 'One-time purchase $15.95'}, {'size': '100 grams', 'price': 'One-time purchase $28.95'}, {'size': '250 grams', 'price': 'One-time purchase $61.95'}, {'size': '500 grams', 'price': 'One-time purchase $111.95'}, {'size': '1 kilogram', 'price': 'One-time purchase $201.95'}, {'size': '120ct 200mg Gel. Caps.', 'price': 'One-time purchase $201.95'}, {'size': '120ct 200mg Veg. Caps.', 'price': 'One-time purchase $201.95'}]
# Cleaned pricing JSON for https://purebulk.com/products/benfotiamine: [{"size": "50 grams", "price": "$15.95"}, {"size": "100 grams", "price": "$28.95"}, {"size": "250 grams", "price": "$61.95"}, {"size": "500 grams", "price": "$111.95"}, {"size": "1 kilogram", "price": "$201.95"}, {"size": "120ct 200mg Gel. Caps.", "price": "$201.95"}, {"size": "120ct 200mg Veg. Caps.", "price": "$201.95"}]
# Raw pricing for https://purebulk.com/products/berberine-hcl: [{'size': '25 grams', 'price': 'One-time purchase $12.50'}, {'size': '50 grams', 'price': 'One-time purchase $22.50'}, {'size': '100 grams', 'price': 'One-time purchase $40.50'}, {'size': '250 grams', 'price': 'One-time purchase $86.50'}, {'size': '500 grams', 'price': 'One-time purchase $155.95'}, {'size': '1 kilogram', 'price': 'One-time purchase $281.95'}, {'size': '120ct 250mg Gel. Caps.', 'price': 'One-time purchase $281.95'}, {'size': '120ct 250mg Veg. Caps.', 'price': 'One-time purchase $281.95'}]
# Cleaned pricing JSON for https://purebulk.com/products/berberine-hcl: [{"size": "25 grams", "price": "$12.50"}, {"size": "50 grams", "price": "$22.50"}, {"size": "100 grams", "price": "$40.50"}, {"size": "250 grams", "price": "$86.50"}, {"size": "500 grams", "price": "$155.95"}, {"size": "1 kilogram", "price": "$281.95"}, {"size": "120ct 250mg Gel. Caps.", "price": "$281.95"}, {"size": "120ct 250mg Veg. Caps.", "price": "$281.95"}]
# Raw pricing for https://purebulk.com/products/beta-alanine-powder: [{'size': '50 grams', 'price': 'One-time purchase $2.50'}, {'size': '100 grams', 'price': 'One-time purchase $4.50'}, {'size': '250 grams', 'price': 'One-time purchase $9.75'}, {'size': '500 grams', 'price': 'One-time purchase $17.75'}, {'size': '1 kilogram', 'price': 'One-time purchase $31.95'}, {'size': '1.5 kilograms', 'price': 'One-time purchase $45.75'}, {'size': '120ct 800mg Veg. Caps.', 'price': 'One-time purchase $45.75'}, {'size': '120ct 800mg Gel. Caps.', 'price': 'One-time purchase $45.75'}, {'size': '300ct 800mg Veg. Caps.', 'price': 'One-time purchase $45.75'}, {'size': '300ct 800mg Gel. Caps.', 'price': 'One-time purchase $45.75'}]
# Cleaned pricing JSON for https://purebulk.com/products/beta-alanine-powder: [{"size": "50 grams", "price": "$2.50"}, {"size": "100 grams", "price": "$4.50"}, {"size": "250 grams", "price": "$9.75"}, {"size": "500 grams", "price": "$17.75"}, {"size": "1 kilogram", "price": "$31.95"}, {"size": "1.5 kilograms", "price": "$45.75"}, {"size": "120ct 800mg Veg. Caps.", "price": "$45.75"}, {"size": "120ct 800mg Gel. Caps.", "price": "$45.75"}, {"size": "300ct 800mg Veg. Caps.", "price": "$45.75"}, {"size": "300ct 800mg Gel. Caps.", "price": "$45.75"}]
# Raw pricing for https://purebulk.com/products/beta-carotene-1-provitamin-a: [{'size': '100 grams', 'price': 'One-time purchase $11.50'}, {'size': '250 grams', 'price': 'One-time purchase $24.75'}, {'size': '500 grams', 'price': 'One-time purchase $44.75'}, {'size': '1 kilogram', 'price': 'One-time purchase $80.95'}, {'size': '120ct 600mg Veg. Caps.', 'price': 'One-time purchase $80.95'}, {'size': '120ct 600mg Gel. Caps.', 'price': 'One-time purchase $80.95'}]
# Cleaned pricing JSON for https://purebulk.com/products/beta-carotene-1-provitamin-a: [{"size": "100 grams", "price": "$11.50"}, {"size": "250 grams", "price": "$24.75"}, {"size": "500 grams", "price": "$44.75"}, {"size": "1 kilogram", "price": "$80.95"}, {"size": "120ct 600mg Veg. Caps.", "price": "$80.95"}, {"size": "120ct 600mg Gel. Caps.", "price": "$80.95"}]
# Raw pricing for https://purebulk.com/products/beta-sitosterol-plant-sterol: [{'size': '100 grams', 'price': 'One-time purchase $10.50'}, {'size': '250 grams', 'price': 'One-time purchase $22.50'}, {'size': '500 grams', 'price': 'One-time purchase $40.50'}, {'size': '750 grams', 'price': 'One-time purchase $57.95'}, {'size': '120ct 500mg Veg. Caps.', 'price': 'One-time purchase $57.95'}, {'size': '120ct 500mg Gel. Caps.', 'price': 'One-time purchase $57.95'}, {'size': '300ct 500mg Gel. Caps.', 'price': 'One-time purchase $57.95'}, {'size': '300ct 500mg Veg. Caps.', 'price': 'One-time purchase $57.95'}]
# Cleaned pricing JSON for https://purebulk.com/products/beta-sitosterol-plant-sterol: [{"size": "100 grams", "price": "$10.50"}, {"size": "250 grams", "price": "$22.50"}, {"size": "500 grams", "price": "$40.50"}, {"size": "750 grams", "price": "$57.95"}, {"size": "120ct 500mg Veg. Caps.", "price": "$57.95"}, {"size": "120ct 500mg Gel. Caps.", "price": "$57.95"}, {"size": "300ct 500mg Gel. Caps.", "price": "$57.95"}, {"size": "300ct 500mg Veg. Caps.", "price": "$57.95"}]
# Raw pricing for https://purebulk.com/products/betaine-anhydrous-tmg: [{'size': '250 grams', 'price': 'One-time purchase $9.25'}, {'size': '500 grams', 'price': 'One-time purchase $16.75'}, {'size': '1 kilogram', 'price': 'One-time purchase $30.25'}, {'size': '1.5 kilograms', 'price': 'One-time purchase $43.25'}, {'size': '300ct 750mg Veg. Caps', 'price': 'One-time purchase $43.25'}, {'size': '300ct 750mg Gel. Caps', 'price': 'One-time purchase $43.25'}]
# Cleaned pricing JSON for https://purebulk.com/products/betaine-anhydrous-tmg: [{"size": "250 grams", "price": "$9.25"}, {"size": "500 grams", "price": "$16.75"}, {"size": "1 kilogram", "price": "$30.25"}, {"size": "1.5 kilograms", "price": "$43.25"}, {"size": "300ct 750mg Veg. Caps", "price": "$43.25"}, {"size": "300ct 750mg Gel. Caps", "price": "$43.25"}]
# Raw pricing for https://purebulk.com/products/betaine-hcl-powder: [{'size': '250 grams', 'price': 'One-time purchase $9.50'}, {'size': '500 grams', 'price': 'One-time purchase $17.25'}, {'size': '1 kilogram', 'price': 'One-time purchase $31.25'}, {'size': '1.5 kilograms', 'price': 'One-time purchase $44.50'}, {'size': '300ct 700mg Veg. Caps.', 'price': 'One-time purchase $44.50'}, {'size': '300ct 700mg Gel. Caps.', 'price': 'One-time purchase $44.50'}]
# Cleaned pricing JSON for https://purebulk.com/products/betaine-hcl-powder: [{"size": "250 grams", "price": "$9.50"}, {"size": "500 grams", "price": "$17.25"}, {"size": "1 kilogram", "price": "$31.25"}, {"size": "1.5 kilograms", "price": "$44.50"}, {"size": "300ct 700mg Veg. Caps.", "price": "$44.50"}, {"size": "300ct 700mg Gel. Caps.", "price": "$44.50"}]
# Raw pricing for https://purebulk.com/products/bhb-calcium: [{'size': '100 grams', 'price': 'One-time purchase $9.38'}, {'size': '250 grams', 'price': 'One-time purchase $20.06'}, {'size': '500 grams', 'price': 'One-time purchase $36.19'}, {'size': '1 kilogram', 'price': 'One-time purchase $21.74'}]
# Cleaned pricing JSON for https://purebulk.com/products/bhb-calcium: [{"size": "100 grams", "price": "$9.38"}, {"size": "250 grams", "price": "$20.06"}, {"size": "500 grams", "price": "$36.19"}, {"size": "1 kilogram", "price": "$21.74"}]
# Raw pricing for https://purebulk.com/products/bhb-magnesium: [{'size': '100 grams', 'price': 'One-time purchase $7.31'}, {'size': '250 grams', 'price': 'One-time purchase $15.71'}, {'size': '500 grams', 'price': 'One-time purchase $28.46'}, {'size': '1 kilogram', 'price': 'One-time purchase $51.38'}]
# Cleaned pricing JSON for https://purebulk.com/products/bhb-magnesium: [{"size": "100 grams", "price": "$7.31"}, {"size": "250 grams", "price": "$15.71"}, {"size": "500 grams", "price": "$28.46"}, {"size": "1 kilogram", "price": "$51.38"}]
# Raw pricing for https://purebulk.com/products/bhb-potassium: [{'size': '100 grams', 'price': 'One-time purchase $6.56'}, {'size': '250 grams', 'price': 'One-time purchase $14.06'}, {'size': '500 grams', 'price': 'One-time purchase $25.31'}, {'size': '1 kilogram', 'price': 'One-time purchase $45.72'}]
# Cleaned pricing JSON for https://purebulk.com/products/bhb-potassium: [{"size": "100 grams", "price": "$6.56"}, {"size": "250 grams", "price": "$14.06"}, {"size": "500 grams", "price": "$25.31"}, {"size": "1 kilogram", "price": "$45.72"}]
# Raw pricing for https://purebulk.com/products/bhb-sodium-beta-hydroxybutyrate: [{'size': '100 grams', 'price': 'One-time purchase $7.12'}, {'size': '250 grams', 'price': 'One-time purchase $15.38'}, {'size': '500 grams', 'price': 'One-time purchase $27.71'}, {'size': '1 kilogram', 'price': 'One-time purchase $46.88'}]
# Cleaned pricing JSON for https://purebulk.com/products/bhb-sodium-beta-hydroxybutyrate: [{"size": "100 grams", "price": "$7.12"}, {"size": "250 grams", "price": "$15.38"}, {"size": "500 grams", "price": "$27.71"}, {"size": "1 kilogram", "price": "$46.88"}]
# Raw pricing for https://purebulk.com/products/bilberry-extract-25-anthocyanins: [{'size': '10 grams', 'price': 'One-time purchase $16.95'}, {'size': '25 grams', 'price': 'One-time purchase $36.50'}, {'size': '50 grams', 'price': 'One-time purchase $65.95'}, {'size': '100 grams', 'price': 'One-time purchase $118.95'}, {'size': '250 grams', 'price': 'One-time purchase $255.95'}, {'size': '500 grams', 'price': 'One-time purchase $461.95'}]
# Cleaned pricing JSON for https://purebulk.com/products/bilberry-extract-25-anthocyanins: [{"size": "10 grams", "price": "$16.95"}, {"size": "25 grams", "price": "$36.50"}, {"size": "50 grams", "price": "$65.95"}, {"size": "100 grams", "price": "$118.95"}, {"size": "250 grams", "price": "$255.95"}, {"size": "500 grams", "price": "$461.95"}]
# Raw pricing for https://purebulk.com/products/biotin-1-vitamin-b7: [{'size': '100 grams', 'price': 'One-time purchase $12.95'}, {'size': '250 grams', 'price': 'One-time purchase $27.75'}, {'size': '500 grams', 'price': 'One-time purchase $49.95'}, {'size': '1 kilogram', 'price': 'One-time purchase $89.95'}, {'size': '1.5 kilograms', 'price': 'One-time purchase $128.95'}, {'size': '120ct 500mg Gel. Caps.', 'price': 'One-time purchase $128.95'}, {'size': '120ct 500mg Veg. Caps.', 'price': 'One-time purchase $128.95'}, {'size': '300ct 500mg Veg. Caps.', 'price': 'One-time purchase $128.95'}]
# Cleaned pricing JSON for https://purebulk.com/products/biotin-1-vitamin-b7: [{"size": "100 grams", "price": "$12.95"}, {"size": "250 grams", "price": "$27.75"}, {"size": "500 grams", "price": "$49.95"}, {"size": "1 kilogram", "price": "$89.95"}, {"size": "1.5 kilograms", "price": "$128.95"}, {"size": "120ct 500mg Gel. Caps.", "price": "$128.95"}, {"size": "120ct 500mg Veg. Caps.", "price": "$128.95"}, {"size": "300ct 500mg Veg. Caps.", "price": "$128.95"}]
# Raw pricing for https://purebulk.com/products/biotin-pure-vitamin-b7: [{'size': '10 grams', 'price': 'One-time purchase $25.85'}, {'size': '25 grams', 'price': 'One-time purchase $55.55'}, {'size': '50 grams', 'price': 'One-time purchase $100.65'}, {'size': '100 grams', 'price': 'One-time purchase $180.40'}, {'size': '250 grams', 'price': 'One-time purchase $387.20'}, {'size': '500 grams', 'price': 'One-time purchase $699.05'}, {'size': '120ct 100mg Gel. Caps.', 'price': 'One-time purchase $699.05'}, {'size': '120ct 100mg Veg. Caps.', 'price': 'One-time purchase $699.05'}]
# Cleaned pricing JSON for https://purebulk.com/products/biotin-pure-vitamin-b7: [{"size": "10 grams", "price": "$25.85"}, {"size": "25 grams", "price": "$55.55"}, {"size": "50 grams", "price": "$100.65"}, {"size": "100 grams", "price": "$180.40"}, {"size": "250 grams", "price": "$387.20"}, {"size": "500 grams", "price": "$699.05"}, {"size": "120ct 100mg Gel. Caps.", "price": "$699.05"}, {"size": "120ct 100mg Veg. Caps.", "price": "$699.05"}]
# Raw pricing for https://purebulk.com/products/boron-glycinate: [{'size': '50 grams', 'price': 'One-time purchase $5.50'}, {'size': '100 grams', 'price': 'One-time purchase $9.95'}, {'size': '250 grams', 'price': 'One-time purchase $21.50'}, {'size': '500 grams', 'price': 'One-time purchase $38.75'}, {'size': '1 kilogram', 'price': 'One-time purchase $69.95'}, {'size': '300ct 500mg Veg. Caps', 'price': 'One-time purchase $69.95'}, {'size': '300ct 500mg Gel. Caps', 'price': 'One-time purchase $69.95'}]
# Cleaned pricing JSON for https://purebulk.com/products/boron-glycinate: [{"size": "50 grams", "price": "$5.50"}, {"size": "100 grams", "price": "$9.95"}, {"size": "250 grams", "price": "$21.50"}, {"size": "500 grams", "price": "$38.75"}, {"size": "1 kilogram", "price": "$69.95"}, {"size": "300ct 500mg Veg. Caps", "price": "$69.95"}, {"size": "300ct 500mg Gel. Caps", "price": "$69.95"}]
# Raw pricing for https://purebulk.com/products/bovine-beef-bone-broth-powder: [{'size': '500 grams', 'price': 'One-time purchase $24.95'}, {'size': '1 kilogram', 'price': 'One-time purchase $42.50'}]
# Cleaned pricing JSON for https://purebulk.com/products/bovine-beef-bone-broth-powder: [{"size": "500 grams", "price": "$24.95"}, {"size": "1 kilogram", "price": "$42.50"}]
# Raw pricing for https://purebulk.com/products/branched-chain-amino-acids-bcaa-instantized: [{'size': '100 grams', 'price': 'One-time purchase $7.25'}, {'size': '250 grams', 'price': 'One-time purchase $15.50'}, {'size': '500 grams', 'price': 'One-time purchase $27.95'}, {'size': '1 kilogram', 'price': 'One-time purchase $50.50'}]
# Cleaned pricing JSON for https://purebulk.com/products/branched-chain-amino-acids-bcaa-instantized: [{"size": "100 grams", "price": "$7.25"}, {"size": "250 grams", "price": "$15.50"}, {"size": "500 grams", "price": "$27.95"}, {"size": "1 kilogram", "price": "$50.50"}]
# Raw pricing for https://purebulk.com/products/bromelain: [{'size': '50 grams', 'price': 'One-time purchase $12.25'}, {'size': '100 grams', 'price': 'One-time purchase $22.25'}, {'size': '250 grams', 'price': 'One-time purchase $47.50'}, {'size': '500 grams', 'price': 'One-time purchase $85.50'}, {'size': '1 kilogram', 'price': 'One-time purchase $153.95'}, {'size': '1.5 kilograms', 'price': 'One-time purchase $219.95'}, {'size': '120ct 500mg Veg. Caps.', 'price': 'One-time purchase $219.95'}, {'size': '120ct 500mg Gel. Caps.', 'price': 'One-time purchase $219.95'}]
# Cleaned pricing JSON for https://purebulk.com/products/bromelain: [{"size": "50 grams", "price": "$12.25"}, {"size": "100 grams", "price": "$22.25"}, {"size": "250 grams", "price": "$47.50"}, {"size": "500 grams", "price": "$85.50"}, {"size": "1 kilogram", "price": "$153.95"}, {"size": "1.5 kilograms", "price": "$219.95"}, {"size": "120ct 500mg Veg. Caps.", "price": "$219.95"}, {"size": "120ct 500mg Gel. Caps.", "price": "$219.95"}]
# Raw pricing for https://purebulk.com/products/caffeine-powder-pure: [{'size': '25 grams', 'price': 'One-time purchase $219.95'}, {'size': '50 grams', 'price': 'One-time purchase $219.95'}, {'size': '100 grams', 'price': 'One-time purchase $219.95'}, {'size': '250 grams', 'price': 'One-time purchase $219.95'}, {'size': '500 grams', 'price': 'One-time purchase $219.95'}, {'size': '1 kilogram', 'price': 'One-time purchase $219.95'}]
# Cleaned pricing JSON for https://purebulk.com/products/caffeine-powder-pure: [{"size": "25 grams", "price": "$219.95"}, {"size": "50 grams", "price": "$219.95"}, {"size": "100 grams", "price": "$219.95"}, {"size": "250 grams", "price": "$219.95"}, {"size": "500 grams", "price": "$219.95"}, {"size": "1 kilogram", "price": "$219.95"}]
# Raw pricing for https://purebulk.com/products/caffeine-powder-pure-natural-coffee-bean: [{'size': '25 grams', 'price': 'One-time purchase $219.95'}, {'size': '50 grams', 'price': 'One-time purchase $219.95'}, {'size': '100 grams', 'price': 'One-time purchase $219.95'}, {'size': '250 grams', 'price': 'One-time purchase $219.95'}, {'size': '500 grams', 'price': 'One-time purchase $219.95'}, {'size': '1 kilogram', 'price': 'One-time purchase $219.95'}]
# Cleaned pricing JSON for https://purebulk.com/products/caffeine-powder-pure-natural-coffee-bean: [{"size": "25 grams", "price": "$219.95"}, {"size": "50 grams", "price": "$219.95"}, {"size": "100 grams", "price": "$219.95"}, {"size": "250 grams", "price": "$219.95"}, {"size": "500 grams", "price": "$219.95"}, {"size": "1 kilogram", "price": "$219.95"}]
# Raw pricing for https://purebulk.com/products/calcium-ascorbate-vitamin-c: [{'size': '100 grams', 'price': 'One-time purchase $5.75'}, {'size': '250 grams', 'price': 'One-time purchase $12.50'}, {'size': '500 grams', 'price': 'One-time purchase $22.50'}, {'size': '1 kilogram', 'price': 'One-time purchase $40.50'}, {'size': '1.5 kilograms', 'price': 'One-time purchase $57.95'}, {'size': '300ct 550mg Gel. Caps', 'price': 'One-time purchase $57.95'}, {'size': '300ct 550mg Veg. Caps', 'price': 'One-time purchase $57.95'}]
# Cleaned pricing JSON for https://purebulk.com/products/calcium-ascorbate-vitamin-c: [{"size": "100 grams", "price": "$5.75"}, {"size": "250 grams", "price": "$12.50"}, {"size": "500 grams", "price": "$22.50"}, {"size": "1 kilogram", "price": "$40.50"}, {"size": "1.5 kilograms", "price": "$57.95"}, {"size": "300ct 550mg Gel. Caps", "price": "$57.95"}, {"size": "300ct 550mg Veg. Caps", "price": "$57.95"}]
# Raw pricing for https://purebulk.com/products/calcium-carbonate-mineral: [{'size': '500 grams', 'price': 'One-time purchase $10.50'}, {'size': '1 kilogram', 'price': 'One-time purchase $18.95'}, {'size': '1.5 kilograms', 'price': 'One-time purchase $27.25'}]
# Cleaned pricing JSON for https://purebulk.com/products/calcium-carbonate-mineral: [{"size": "500 grams", "price": "$10.50"}, {"size": "1 kilogram", "price": "$18.95"}, {"size": "1.5 kilograms", "price": "$27.25"}]
# Raw pricing for https://purebulk.com/products/calcium-citrate-usa: [{'size': '500 grams', 'price': 'One-time purchase $27.75'}, {'size': '1 kilogram', 'price': 'One-time purchase $49.95'}, {'size': '1.5 kilograms', 'price': 'One-time purchase $71.50'}]
# Cleaned pricing JSON for https://purebulk.com/products/calcium-citrate-usa: [{"size": "500 grams", "price": "$27.75"}, {"size": "1 kilogram", "price": "$49.95"}, {"size": "1.5 kilograms", "price": "$71.50"}]
# Raw pricing for https://purebulk.com/products/calcium-d-glucarate: [{'size': '25 grams', 'price': 'One-time purchase $10.95'}, {'size': '50 grams', 'price': 'One-time purchase $19.25'}, {'size': '100 grams', 'price': 'One-time purchase $32.95'}, {'size': '250 grams', 'price': 'One-time purchase $70.50'}, {'size': '500 grams', 'price': 'One-time purchase $126.95'}, {'size': '1 kilogram', 'price': 'One-time purchase $228.95'}, {'size': '1.5 kilograms', 'price': 'One-time purchase $325.95'}]
# Cleaned pricing JSON for https://purebulk.com/products/calcium-d-glucarate: [{"size": "25 grams", "price": "$10.95"}, {"size": "50 grams", "price": "$19.25"}, {"size": "100 grams", "price": "$32.95"}, {"size": "250 grams", "price": "$70.50"}, {"size": "500 grams", "price": "$126.95"}, {"size": "1 kilogram", "price": "$228.95"}, {"size": "1.5 kilograms", "price": "$325.95"}]
# Raw pricing for https://purebulk.com/products/calcium-gluconate: [{'size': '250 grams', 'price': 'One-time purchase $22.55'}, {'size': '500 grams', 'price': 'One-time purchase $40.70'}]
# Cleaned pricing JSON for https://purebulk.com/products/calcium-gluconate: [{"size": "250 grams", "price": "$22.55"}, {"size": "500 grams", "price": "$40.70"}]
# Raw pricing for https://purebulk.com/products/calcium-hmb: [{'size': '100 grams', 'price': 'One-time purchase $11.95'}, {'size': '250 grams', 'price': 'One-time purchase $25.75'}, {'size': '500 grams', 'price': 'One-time purchase $46.50'}, {'size': '1 kilogram', 'price': 'One-time purchase $83.95'}, {'size': '120ct 500mg Gel. Caps.', 'price': 'One-time purchase $83.95'}, {'size': '120ct 500mg Veg. Caps.', 'price': 'One-time purchase $83.95'}]
# Cleaned pricing JSON for https://purebulk.com/products/calcium-hmb: [{"size": "100 grams", "price": "$11.95"}, {"size": "250 grams", "price": "$25.75"}, {"size": "500 grams", "price": "$46.50"}, {"size": "1 kilogram", "price": "$83.95"}, {"size": "120ct 500mg Gel. Caps.", "price": "$83.95"}, {"size": "120ct 500mg Veg. Caps.", "price": "$83.95"}]
# Raw pricing for https://purebulk.com/products/calcium-lactate-gluconate: [{'size': '100 grams', 'price': 'One-time purchase $9.95'}, {'size': '250 grams', 'price': 'One-time purchase $21.50'}, {'size': '500 grams', 'price': 'One-time purchase $38.75'}, {'size': '1 kilogram', 'price': 'One-time purchase $69.95'}, {'size': '300ct 650mg Gel. Caps.', 'price': 'One-time purchase $69.95'}, {'size': '300ct 650mg Veg. Caps.', 'price': 'One-time purchase $69.95'}]
# Cleaned pricing JSON for https://purebulk.com/products/calcium-lactate-gluconate: [{"size": "100 grams", "price": "$9.95"}, {"size": "250 grams", "price": "$21.50"}, {"size": "500 grams", "price": "$38.75"}, {"size": "1 kilogram", "price": "$69.95"}, {"size": "300ct 650mg Gel. Caps.", "price": "$69.95"}, {"size": "300ct 650mg Veg. Caps.", "price": "$69.95"}]
# Raw pricing for https://purebulk.com/products/calcium-pyruvate: [{'size': '100 grams', 'price': 'One-time purchase $12.95'}, {'size': '250 grams', 'price': 'One-time purchase $27.75'}, {'size': '500 grams', 'price': 'One-time purchase $49.95'}, {'size': '1 kilogram', 'price': 'One-time purchase $89.95'}, {'size': '1.5 kilograms', 'price': 'One-time purchase $128.95'}, {'size': '120ct 900mg Veg. Caps.', 'price': 'One-time purchase $128.95'}, {'size': '120ct 900mg Gel. Caps.', 'price': 'One-time purchase $128.95'}]
# Cleaned pricing JSON for https://purebulk.com/products/calcium-pyruvate: [{"size": "100 grams", "price": "$12.95"}, {"size": "250 grams", "price": "$27.75"}, {"size": "500 grams", "price": "$49.95"}, {"size": "1 kilogram", "price": "$89.95"}, {"size": "1.5 kilograms", "price": "$128.95"}, {"size": "120ct 900mg Veg. Caps.", "price": "$128.95"}, {"size": "120ct 900mg Gel. Caps.", "price": "$128.95"}]
# Raw pricing for https://purebulk.com/products/casein-protein-100-micellar: [{'size': '500 grams', 'price': 'One-time purchase $16.75'}, {'size': '1 kilogram', 'price': 'One-time purchase $29.95'}]
# Cleaned pricing JSON for https://purebulk.com/products/casein-protein-100-micellar: [{"size": "500 grams", "price": "$16.75"}, {"size": "1 kilogram", "price": "$29.95"}]
# Raw pricing for https://purebulk.com/products/cayenne-pepper-capsicum: [{'size': '250 grams', 'price': 'One-time purchase $12.50'}, {'size': '1 kilogram', 'price': 'One-time purchase $40.50'}, {'size': '300ct 500mg Gel. Caps', 'price': 'One-time purchase $40.50'}, {'size': '300ct 500mg Veg. Caps', 'price': 'One-time purchase $40.50'}]
# Cleaned pricing JSON for https://purebulk.com/products/cayenne-pepper-capsicum: [{"size": "250 grams", "price": "$12.50"}, {"size": "1 kilogram", "price": "$40.50"}, {"size": "300ct 500mg Gel. Caps", "price": "$40.50"}, {"size": "300ct 500mg Veg. Caps", "price": "$40.50"}]
# Raw pricing for https://purebulk.com/products/chaga-mushroom-extract-4-1: [{'size': '100 grams', 'price': 'One-time purchase $12.50'}, {'size': '250 grams', 'price': 'One-time purchase $26.75'}, {'size': '500 grams', 'price': 'One-time purchase $48.25'}, {'size': '1 kilogram', 'price': 'One-time purchase $86.95'}, {'size': '120ct 500mg Veg. Caps.', 'price': 'One-time purchase $86.95'}, {'size': '120ct 500mg Gel. Caps.', 'price': 'One-time purchase $86.95'}]
# Cleaned pricing JSON for https://purebulk.com/products/chaga-mushroom-extract-4-1: [{"size": "100 grams", "price": "$12.50"}, {"size": "250 grams", "price": "$26.75"}, {"size": "500 grams", "price": "$48.25"}, {"size": "1 kilogram", "price": "$86.95"}, {"size": "120ct 500mg Veg. Caps.", "price": "$86.95"}, {"size": "120ct 500mg Gel. Caps.", "price": "$86.95"}]
# Raw pricing for https://purebulk.com/products/chicken-bone-broth: [{'size': '500 grams', 'price': 'One-time purchase $86.95'}, {'size': '1 kilogram', 'price': 'One-time purchase $86.95'}]
# Cleaned pricing JSON for https://purebulk.com/products/chicken-bone-broth: [{"size": "500 grams", "price": "$86.95"}, {"size": "1 kilogram", "price": "$86.95"}]
# Raw pricing for https://purebulk.com/products/chlorella-broken-cell-wall: [{'size': '100 grams', 'price': 'One-time purchase $12.50'}, {'size': '250 grams', 'price': 'One-time purchase $26.75'}, {'size': '500 grams', 'price': 'One-time purchase $48.25'}, {'size': '1 kilogram', 'price': 'One-time purchase $86.95'}, {'size': '1.5 kilograms', 'price': 'One-time purchase $123.95'}, {'size': '120ct 450mg Veg. Caps.', 'price': 'One-time purchase $123.95'}, {'size': '120ct 450mg Gel. Caps.', 'price': 'One-time purchase $123.95'}]
# Cleaned pricing JSON for https://purebulk.com/products/chlorella-broken-cell-wall: [{"size": "100 grams", "price": "$12.50"}, {"size": "250 grams", "price": "$26.75"}, {"size": "500 grams", "price": "$48.25"}, {"size": "1 kilogram", "price": "$86.95"}, {"size": "1.5 kilograms", "price": "$123.95"}, {"size": "120ct 450mg Veg. Caps.", "price": "$123.95"}, {"size": "120ct 450mg Gel. Caps.", "price": "$123.95"}]
# Raw pricing for https://purebulk.com/products/cholecalciferol-vitamin-d3: [{'size': '25 grams', 'price': 'One-time purchase $2.75'}, {'size': '50 grams', 'price': 'One-time purchase $4.95'}, {'size': '100 grams', 'price': 'One-time purchase $8.95'}, {'size': '250 grams', 'price': 'One-time purchase $19.25'}, {'size': '500 grams', 'price': 'One-time purchase $34.75'}, {'size': '1 kilogram', 'price': 'One-time purchase $62.95'}]
# Cleaned pricing JSON for https://purebulk.com/products/cholecalciferol-vitamin-d3: [{"size": "25 grams", "price": "$2.75"}, {"size": "50 grams", "price": "$4.95"}, {"size": "100 grams", "price": "$8.95"}, {"size": "250 grams", "price": "$19.25"}, {"size": "500 grams", "price": "$34.75"}, {"size": "1 kilogram", "price": "$62.95"}]
# Raw pricing for https://purebulk.com/products/choline-l-bitartrate: [{'size': '100 grams', 'price': 'One-time purchase $6.95'}, {'size': '250 grams', 'price': 'One-time purchase $14.95'}, {'size': '500 grams', 'price': 'One-time purchase $26.95'}, {'size': '1 kilogram', 'price': 'One-time purchase $48.75'}, {'size': '1.5 kilograms', 'price': 'One-time purchase $69.50'}, {'size': '300ct 700mg Gel. Caps.', 'price': 'One-time purchase $69.50'}, {'size': '300ct 700mg Veg. Caps.', 'price': 'One-time purchase $69.50'}]
# Cleaned pricing JSON for https://purebulk.com/products/choline-l-bitartrate: [{"size": "100 grams", "price": "$6.95"}, {"size": "250 grams", "price": "$14.95"}, {"size": "500 grams", "price": "$26.95"}, {"size": "1 kilogram", "price": "$48.75"}, {"size": "1.5 kilograms", "price": "$69.50"}, {"size": "300ct 700mg Gel. Caps.", "price": "$69.50"}, {"size": "300ct 700mg Veg. Caps.", "price": "$69.50"}]
# Raw pricing for https://purebulk.com/products/chondroitin-sulfate: [{'size': '100 grams', 'price': 'One-time purchase $17.95'}, {'size': '250 grams', 'price': 'One-time purchase $38.50'}, {'size': '500 grams', 'price': 'One-time purchase $69.50'}, {'size': '1 kilogram', 'price': 'One-time purchase $125.95'}, {'size': '1.5 kilograms', 'price': 'One-time purchase $179.95'}, {'size': '120ct 750mg Gel. Caps.', 'price': 'One-time purchase $179.95'}]
# Cleaned pricing JSON for https://purebulk.com/products/chondroitin-sulfate: [{"size": "100 grams", "price": "$17.95"}, {"size": "250 grams", "price": "$38.50"}, {"size": "500 grams", "price": "$69.50"}, {"size": "1 kilogram", "price": "$125.95"}, {"size": "1.5 kilograms", "price": "$179.95"}, {"size": "120ct 750mg Gel. Caps.", "price": "$179.95"}]
# Raw pricing for https://purebulk.com/products/cissus-quadrangularis-extract: [{'size': '100 grams', 'price': 'One-time purchase $9.25'}, {'size': '250 grams', 'price': 'One-time purchase $19.75'}, {'size': '500 grams', 'price': 'One-time purchase $35.75'}, {'size': '1 kilogram', 'price': 'One-time purchase $64.50'}, {'size': '1.5 kilograms', 'price': 'One-time purchase $91.95'}]
# Cleaned pricing JSON for https://purebulk.com/products/cissus-quadrangularis-extract: [{"size": "100 grams", "price": "$9.25"}, {"size": "250 grams", "price": "$19.75"}, {"size": "500 grams", "price": "$35.75"}, {"size": "1 kilogram", "price": "$64.50"}, {"size": "1.5 kilograms", "price": "$91.95"}]
# Raw pricing for https://purebulk.com/products/citric-acid: [{'size': '1 kilogram', 'price': 'One-time purchase $19.25'}]
# Cleaned pricing JSON for https://purebulk.com/products/citric-acid: [{"size": "1 kilogram", "price": "$19.25"}]
# Raw pricing for https://purebulk.com/products/coenzyme-q10-coq10: [{'size': '10 grams', 'price': 'One-time purchase $9.25'}, {'size': '25 grams', 'price': 'One-time purchase $19.75'}, {'size': '50 grams', 'price': 'One-time purchase $35.75'}, {'size': '100 grams', 'price': 'One-time purchase $64.50'}, {'size': '250 grams', 'price': 'One-time purchase $137.95'}, {'size': '500 grams', 'price': 'One-time purchase $248.95'}, {'size': '1 kilogram', 'price': 'One-time purchase $449.95'}]
# Cleaned pricing JSON for https://purebulk.com/products/coenzyme-q10-coq10: [{"size": "10 grams", "price": "$9.25"}, {"size": "25 grams", "price": "$19.75"}, {"size": "50 grams", "price": "$35.75"}, {"size": "100 grams", "price": "$64.50"}, {"size": "250 grams", "price": "$137.95"}, {"size": "500 grams", "price": "$248.95"}, {"size": "1 kilogram", "price": "$449.95"}]
# Raw pricing for https://purebulk.com/products/copper-gluconate-pure: [{'size': '50 grams', 'price': 'One-time purchase $5.50'}, {'size': '100 grams', 'price': 'One-time purchase $9.95'}, {'size': '250 grams', 'price': 'One-time purchase $21.50'}, {'size': '500 grams', 'price': 'One-time purchase $38.75'}, {'size': '1 kilogram', 'price': 'One-time purchase $69.95'}, {'size': '1.5 kilograms', 'price': 'One-time purchase $99.95'}]
# Cleaned pricing JSON for https://purebulk.com/products/copper-gluconate-pure: [{"size": "50 grams", "price": "$5.50"}, {"size": "100 grams", "price": "$9.95"}, {"size": "250 grams", "price": "$21.50"}, {"size": "500 grams", "price": "$38.75"}, {"size": "1 kilogram", "price": "$69.95"}, {"size": "1.5 kilograms", "price": "$99.95"}]
# Raw pricing for https://purebulk.com/products/coral-calcium: [{'size': '100 grams', 'price': 'One-time purchase $8.00'}, {'size': '250 grams', 'price': 'One-time purchase $17.25'}, {'size': '500 grams', 'price': 'One-time purchase $31.25'}, {'size': '1 kilogram', 'price': 'One-time purchase $56.50'}, {'size': '1.5 kilograms', 'price': 'One-time purchase $80.50'}, {'size': '120ct 650mg Gel. Caps.', 'price': 'One-time purchase $80.50'}, {'size': '300ct 650mg Gel. Caps.', 'price': 'One-time purchase $80.50'}]
# Cleaned pricing JSON for https://purebulk.com/products/coral-calcium: [{"size": "100 grams", "price": "$8.00"}, {"size": "250 grams", "price": "$17.25"}, {"size": "500 grams", "price": "$31.25"}, {"size": "1 kilogram", "price": "$56.50"}, {"size": "1.5 kilograms", "price": "$80.50"}, {"size": "120ct 650mg Gel. Caps.", "price": "$80.50"}, {"size": "300ct 650mg Gel. Caps.", "price": "$80.50"}]
# Raw pricing for https://purebulk.com/products/creatine-monohydrate: [{'size': '250 grams', 'price': 'One-time purchase $9.50'}, {'size': '500 grams', 'price': 'One-time purchase $17.25'}, {'size': '1 kilogram', 'price': 'One-time purchase $31.25'}, {'size': '1.5 kilograms', 'price': 'One-time purchase $44.50'}, {'size': '120ct 500mg Veg. Caps.', 'price': 'One-time purchase $44.50'}, {'size': '300ct 500mg Gel. Caps.', 'price': 'One-time purchase $44.50'}, {'size': '300ct 500mg Veg. Caps.', 'price': 'One-time purchase $44.50'}]
# Cleaned pricing JSON for https://purebulk.com/products/creatine-monohydrate: [{"size": "250 grams", "price": "$9.50"}, {"size": "500 grams", "price": "$17.25"}, {"size": "1 kilogram", "price": "$31.25"}, {"size": "1.5 kilograms", "price": "$44.50"}, {"size": "120ct 500mg Veg. Caps.", "price": "$44.50"}, {"size": "300ct 500mg Gel. Caps.", "price": "$44.50"}, {"size": "300ct 500mg Veg. Caps.", "price": "$44.50"}]
# Raw pricing for https://purebulk.com/products/curcumin-95-natural-turmeric-extract: [{'size': '25 grams', 'price': 'One-time purchase $9.50'}, {'size': '50 grams', 'price': 'One-time purchase $17.25'}, {'size': '100 grams', 'price': 'One-time purchase $31.25'}, {'size': '250 grams', 'price': 'One-time purchase $66.95'}, {'size': '500 grams', 'price': 'One-time purchase $120.95'}, {'size': '1 kilogram', 'price': 'One-time purchase $217.95'}]
# Cleaned pricing JSON for https://purebulk.com/products/curcumin-95-natural-turmeric-extract: [{"size": "25 grams", "price": "$9.50"}, {"size": "50 grams", "price": "$17.25"}, {"size": "100 grams", "price": "$31.25"}, {"size": "250 grams", "price": "$66.95"}, {"size": "500 grams", "price": "$120.95"}, {"size": "1 kilogram", "price": "$217.95"}]
# ...
# Cleaned pricing JSON for https://purebulk.com/products/taurine: [{"size": "250 grams", "price": "$7.75"}, {"size": "500 grams", "price": "$13.95"}, {"size": "1 kilogram", "price": "$25.25"}, {"size": "1.5 kilograms", "price": "$35.95"}, {"size": "300ct 800mg Veg. Caps.", "price": "$35.95"}, {"size": "300ct 800mg Gel. Caps.", "price": "$35.95"}]
# Raw pricing for https://purebulk.com/products/theobromine-pure: [{'size': '50 grams', 'price': 'One-time purchase $16.25'}, {'size': '100 grams', 'price': 'One-time purchase $29.25'}, {'size': '250 grams', 'price': 'One-time purchase $62.50'}, {'size': '500 grams', 'price': 'One-time purchase $112.95'}, {'size': '1 kilogram', 'price': 'One-time purchase $203.95'}]
# Cleaned pricing JSON for https://purebulk.com/products/theobromine-pure: [{"size": "50 grams", "price": "$16.25"}, {"size": "100 grams", "price": "$29.25"}, {"size": "250 grams", "price": "$62.50"}, {"size": "500 grams", "price": "$112.95"}, {"size": "1 kilogram", "price": "$203.95"}]
# Raw pricing for https://purebulk.com/products/thiamine-hcl-vitamin-b1: [{'size': '25 grams', 'price': 'One-time purchase $5.25'}, {'size': '50 grams', 'price': 'One-time purchase $9.50'}, {'size': '100 grams', 'price': 'One-time purchase $17.25'}, {'size': '250 grams', 'price': 'One-time purchase $36.95'}, {'size': '500 grams', 'price': 'One-time purchase $66.95'}, {'size': '1 kilogram', 'price': 'One-time purchase $120.95'}, {'size': '300ct 100mg Gel. Caps.', 'price': 'One-time purchase $120.95'}, {'size': '300ct 100mg Veg. Caps.', 'price': 'One-time purchase $120.95'}]
# Cleaned pricing JSON for https://purebulk.com/products/thiamine-hcl-vitamin-b1: [{"size": "25 grams", "price": "$5.25"}, {"size": "50 grams", "price": "$9.50"}, {"size": "100 grams", "price": "$17.25"}, {"size": "250 grams", "price": "$36.95"}, {"size": "500 grams", "price": "$66.95"}, {"size": "1 kilogram", "price": "$120.95"}, {"size": "300ct 100mg Gel. Caps.", "price": "$120.95"}, {"size": "300ct 100mg Veg. Caps.", "price": "$120.95"}]
# Raw pricing for https://purebulk.com/products/thiamine-mononitrate-vitamin-b1: [{'size': '100 grams', 'price': 'One-time purchase $13.95'}, {'size': '250 grams', 'price': 'One-time purchase $29.95'}, {'size': '500 grams', 'price': 'One-time purchase $53.95'}, {'size': '1 kilogram', 'price': 'One-time purchase $97.50'}, {'size': '1.5 kilograms', 'price': 'One-time purchase $138.95'}]
# Cleaned pricing JSON for https://purebulk.com/products/thiamine-mononitrate-vitamin-b1: [{"size": "100 grams", "price": "$13.95"}, {"size": "250 grams", "price": "$29.95"}, {"size": "500 grams", "price": "$53.95"}, {"size": "1 kilogram", "price": "$97.50"}, {"size": "1.5 kilograms", "price": "$138.95"}]
# Raw pricing for https://purebulk.com/products/resveratrol-50: [{'size': '10 grams', 'price': 'One-time purchase $5.25'}, {'size': '25 grams', 'price': 'One-time purchase $11.25'}, {'size': '50 grams', 'price': 'One-time purchase $20.25'}, {'size': '100 grams', 'price': 'One-time purchase $36.50'}, {'size': '250 grams', 'price': 'One-time purchase $77.95'}, {'size': '500 grams', 'price': 'One-time purchase $140.95'}, {'size': '1 kilogram', 'price': 'One-time purchase $253.95'}]
# Cleaned pricing JSON for https://purebulk.com/products/resveratrol-50: [{"size": "10 grams", "price": "$5.25"}, {"size": "25 grams", "price": "$11.25"}, {"size": "50 grams", "price": "$20.25"}, {"size": "100 grams", "price": "$36.50"}, {"size": "250 grams", "price": "$77.95"}, {"size": "500 grams", "price": "$140.95"}, {"size": "1 kilogram", "price": "$253.95"}]
# Raw pricing for https://purebulk.com/products/resveratrol-pure: [{'size': '10 grams', 'price': 'One-time purchase $7.95'}, {'size': '25 grams', 'price': 'One-time purchase $17.25'}, {'size': '50 grams', 'price': 'One-time purchase $31.25'}, {'size': '100 grams', 'price': 'One-time purchase $56.50'}, {'size': '250 grams', 'price': 'One-time purchase $120.95'}, {'size': '500 grams', 'price': 'One-time purchase $217.95'}, {'size': '1 kilogram', 'price': 'One-time purchase $393.95'}, {'size': '120ct 250mg Veg. Caps.', 'price': 'One-time purchase $393.95'}, {'size': '120ct 250mg Gel. Caps.', 'price': 'One-time purchase $393.95'}]
# Cleaned pricing JSON for https://purebulk.com/products/resveratrol-pure: [{"size": "10 grams", "price": "$7.95"}, {"size": "25 grams", "price": "$17.25"}, {"size": "50 grams", "price": "$31.25"}, {"size": "100 grams", "price": "$56.50"}, {"size": "250 grams", "price": "$120.95"}, {"size": "500 grams", "price": "$217.95"}, {"size": "1 kilogram", "price": "$393.95"}, {"size": "120ct 250mg Veg. Caps.", "price": "$393.95"}, {"size": "120ct 250mg Gel. Caps.", "price": "$393.95"}]
# Raw pricing for https://purebulk.com/products/tribulus-terrestris-extract: [{'size': '50 grams', 'price': 'One-time purchase $4.25'}, {'size': '100 grams', 'price': 'One-time purchase $7.75'}, {'size': '250 grams', 'price': 'One-time purchase $16.75'}, {'size': '500 grams', 'price': 'One-time purchase $30.25'}, {'size': '1 kilogram', 'price': 'One-time purchase $54.50'}, {'size': '1.5 kilograms', 'price': 'One-time purchase $77.95'}, {'size': '300ct 500mg Gel. Caps.', 'price': 'One-time purchase $77.95'}, {'size': '300ct 500mg Veg. Caps.', 'price': 'One-time purchase $77.95'}]
# Cleaned pricing JSON for https://purebulk.com/products/tribulus-terrestris-extract: [{"size": "50 grams", "price": "$4.25"}, {"size": "100 grams", "price": "$7.75"}, {"size": "250 grams", "price": "$16.75"}, {"size": "500 grams", "price": "$30.25"}, {"size": "1 kilogram", "price": "$54.50"}, {"size": "1.5 kilograms", "price": "$77.95"}, {"size": "300ct 500mg Gel. Caps.", "price": "$77.95"}, {"size": "300ct 500mg Veg. Caps.", "price": "$77.95"}]
# Raw pricing for https://purebulk.com/products/tribulus-terrestris-extract-bulk: None
# Error loading pricing for https://purebulk.com/products/tribulus-terrestris-extract-bulk: 'NoneType' object is not iterable
# Raw pricing for https://purebulk.com/products/tricalcium-phosphate: [{'size': '100 grams', 'price': 'One-time purchase $6.50'}, {'size': '250 grams', 'price': 'One-time purchase $13.95'}, {'size': '500 grams', 'price': 'One-time purchase $25.25'}, {'size': '1 kilogram', 'price': 'One-time purchase $45.50'}]
# Cleaned pricing JSON for https://purebulk.com/products/tricalcium-phosphate: [{"size": "100 grams", "price": "$6.50"}, {"size": "250 grams", "price": "$13.95"}, {"size": "500 grams", "price": "$25.25"}, {"size": "1 kilogram", "price": "$45.50"}]
# Raw pricing for https://purebulk.com/products/tudca-tauroursodeoxycholic-acid: [{'size': '10 grams', 'price': 'One-time purchase $21.75'}, {'size': '25 grams', 'price': 'One-time purchase $46.50'}, {'size': '50 grams', 'price': 'One-time purchase $83.95'}, {'size': '100 grams', 'price': 'One-time purchase $151.95'}, {'size': '250 grams', 'price': 'One-time purchase $325.95'}, {'size': '500 grams', 'price': 'One-time purchase $589.95'}, {'size': '120ct 250mg Gel. Caps.', 'price': 'One-time purchase $589.95'}]
# Cleaned pricing JSON for https://purebulk.com/products/tudca-tauroursodeoxycholic-acid: [{"size": "10 grams", "price": "$21.75"}, {"size": "25 grams", "price": "$46.50"}, {"size": "50 grams", "price": "$83.95"}, {"size": "100 grams", "price": "$151.95"}, {"size": "250 grams", "price": "$325.95"}, {"size": "500 grams", "price": "$589.95"}, {"size": "120ct 250mg Gel. Caps.", "price": "$589.95"}]
# Raw pricing for https://purebulk.com/products/turkey-tail-mushroom-extract: [{'size': '100 grams', 'price': 'One-time purchase $8.25'}, {'size': '250 grams', 'price': 'One-time purchase $17.75'}, {'size': '500 grams', 'price': 'One-time purchase $31.95'}, {'size': '1 kilogram', 'price': 'One-time purchase $57.95'}, {'size': '1.5 kilograms', 'price': 'One-time purchase $82.95'}, {'size': '120ct 500mg Veg. Caps.', 'price': 'One-time purchase $82.95'}, {'size': '300ct 500mg Veg. Caps.', 'price': 'One-time purchase $82.95'}, {'size': '120ct 500mg Gel. Caps.', 'price': 'One-time purchase $82.95'}, {'size': '300ct 500mg Gel. Caps.', 'price': 'One-time purchase $82.95'}]
# Cleaned pricing JSON for https://purebulk.com/products/turkey-tail-mushroom-extract: [{"size": "100 grams", "price": "$8.25"}, {"size": "250 grams", "price": "$17.75"}, {"size": "500 grams", "price": "$31.95"}, {"size": "1 kilogram", "price": "$57.95"}, {"size": "1.5 kilograms", "price": "$82.95"}, {"size": "120ct 500mg Veg. Caps.", "price": "$82.95"}, {"size": "300ct 500mg Veg. Caps.", "price": "$82.95"}, {"size": "120ct 500mg Gel. Caps.", "price": "$82.95"}, {"size": "300ct 500mg Gel. Caps.", "price": "$82.95"}]
# Raw pricing for https://purebulk.com/products/varuna-bark-extract: [{'size': '100 grams', 'price': 'One-time purchase $10.25'}, {'size': '250 grams', 'price': 'One-time purchase $21.95'}, {'size': '500 grams', 'price': 'One-time purchase $39.75'}, {'size': '1 kilogram', 'price': 'One-time purchase $71.95'}, {'size': '120ct 500mg Veg. Caps', 'price': 'One-time purchase $71.95'}, {'size': '120ct 500mg Gel. Caps', 'price': 'One-time purchase $71.95'}]
# Cleaned pricing JSON for https://purebulk.com/products/varuna-bark-extract: [{"size": "100 grams", "price": "$10.25"}, {"size": "250 grams", "price": "$21.95"}, {"size": "500 grams", "price": "$39.75"}, {"size": "1 kilogram", "price": "$71.95"}, {"size": "120ct 500mg Veg. Caps", "price": "$71.95"}, {"size": "120ct 500mg Gel. Caps", "price": "$71.95"}]
# Raw pricing for https://purebulk.com/products/whey-protein-isolate-90: [{'size': '500 grams', 'price': 'One-time purchase $28.50'}, {'size': '1 kilogram', 'price': 'One-time purchase $51.50'}]
# Cleaned pricing JSON for https://purebulk.com/products/whey-protein-isolate-90: [{"size": "500 grams", "price": "$28.50"}, {"size": "1 kilogram", "price": "$51.50"}]
# Raw pricing for https://purebulk.com/products/white-kidney-bean-extract: [{'size': '100 grams', 'price': 'One-time purchase $7.43'}, {'size': '250 grams', 'price': 'One-time purchase $15.95'}, {'size': '500 grams', 'price': 'One-time purchase $28.88'}, {'size': '1 kilogram', 'price': 'One-time purchase $52.25'}, {'size': '1.5 kilograms', 'price': 'One-time purchase $74.25'}]
# Cleaned pricing JSON for https://purebulk.com/products/white-kidney-bean-extract: [{"size": "100 grams", "price": "$7.43"}, {"size": "250 grams", "price": "$15.95"}, {"size": "500 grams", "price": "$28.88"}, {"size": "1 kilogram", "price": "$52.25"}, {"size": "1.5 kilograms", "price": "$74.25"}]
# Raw pricing for https://purebulk.com/products/xylitol: [{'size': '500 grams', 'price': 'One-time purchase $15.95'}, {'size': '1 kilogram', 'price': 'One-time purchase $28.95'}, {'size': '1.5 kilograms', 'price': 'One-time purchase $41.50'}]
# Cleaned pricing JSON for https://purebulk.com/products/xylitol: [{"size": "500 grams", "price": "$15.95"}, {"size": "1 kilogram", "price": "$28.95"}, {"size": "1.5 kilograms", "price": "$41.50"}]
# Raw pricing for https://purebulk.com/products/zinc-ascorbate: [{'size': '100 grams', 'price': 'One-time purchase $12.75'}, {'size': '250 grams', 'price': 'One-time purchase $27.25'}, {'size': '500 grams', 'price': 'One-time purchase $49.25'}, {'size': '1 kilogram', 'price': 'One-time purchase $88.95'}, {'size': '1.5 kilograms', 'price': 'One-time purchase $126.95'}, {'size': '120ct 300mg Gel. Caps.', 'price': 'One-time purchase $126.95'}, {'size': '120ct 300mg Veg. Caps', 'price': 'One-time purchase $126.95'}]
# Cleaned pricing JSON for https://purebulk.com/products/zinc-ascorbate: [{"size": "100 grams", "price": "$12.75"}, {"size": "250 grams", "price": "$27.25"}, {"size": "500 grams", "price": "$49.25"}, {"size": "1 kilogram", "price": "$88.95"}, {"size": "1.5 kilograms", "price": "$126.95"}, {"size": "120ct 300mg Gel. Caps.", "price": "$126.95"}, {"size": "120ct 300mg Veg. Caps", "price": "$126.95"}]
# Raw pricing for https://purebulk.com/products/zinc-bis-glycinate: [{'size': '50 grams', 'price': 'One-time purchase $4.75'}, {'size': '100 grams', 'price': 'One-time purchase $8.75'}, {'size': '250 grams', 'price': 'One-time purchase $18.75'}, {'size': '500 grams', 'price': 'One-time purchase $33.75'}, {'size': '1 kilogram', 'price': 'One-time purchase $60.95'}, {'size': '1.5 kilograms', 'price': 'One-time purchase $72.50'}, {'size': '120ct 200mg Gel. Caps.', 'price': 'One-time purchase $72.50'}, {'size': '300ct 200mg Gel. Caps.', 'price': 'One-time purchase $72.50'}, {'size': '120ct 200mg Veg. Caps.', 'price': 'One-time purchase $72.50'}, {'size': '300ct 200mg Veg. Caps.', 'price': 'One-time purchase $72.50'}]
# Cleaned pricing JSON for https://purebulk.com/products/zinc-bis-glycinate: [{"size": "50 grams", "price": "$4.75"}, {"size": "100 grams", "price": "$8.75"}, {"size": "250 grams", "price": "$18.75"}, {"size": "500 grams", "price": "$33.75"}, {"size": "1 kilogram", "price": "$60.95"}, {"size": "1.5 kilograms", "price": "$72.50"}, {"size": "120ct 200mg Gel. Caps.", "price": "$72.50"}, {"size": "300ct 200mg Gel. Caps.", "price": "$72.50"}, {"size": "120ct 200mg Veg. Caps.", "price": "$72.50"}, {"size": "300ct 200mg Veg. Caps.", "price": "$72.50"}]
# Raw pricing for https://purebulk.com/products/zinc-gluconate: [{'size': '100 grams', 'price': 'One-time purchase $6.60'}, {'size': '250 grams', 'price': 'One-time purchase $14.30'}, {'size': '500 grams', 'price': 'One-time purchase $25.85'}, {'size': '1 kilogram', 'price': 'One-time purchase $46.75'}, {'size': '1.5 kilograms', 'price': 'One-time purchase $66.55'}]
# Cleaned pricing JSON for https://purebulk.com/products/zinc-gluconate: [{"size": "100 grams", "price": "$6.60"}, {"size": "250 grams", "price": "$14.30"}, {"size": "500 grams", "price": "$25.85"}, {"size": "1 kilogram", "price": "$46.75"}, {"size": "1.5 kilograms", "price": "$66.55"}]
# Raw pricing for https://purebulk.com/products/zinc-l-aspartate: [{'size': '100 grams', 'price': 'One-time purchase $6.88'}, {'size': '250 grams', 'price': 'One-time purchase $14.85'}, {'size': '500 grams', 'price': 'One-time purchase $26.95'}, {'size': '1 kilogram', 'price': 'One-time purchase $48.68'}, {'size': '1.5 kilograms', 'price': 'One-time purchase $69.30'}]
# Cleaned pricing JSON for https://purebulk.com/products/zinc-l-aspartate: [{"size": "100 grams", "price": "$6.88"}, {"size": "250 grams", "price": "$14.85"}, {"size": "500 grams", "price": "$26.95"}, {"size": "1 kilogram", "price": "$48.68"}, {"size": "1.5 kilograms", "price": "$69.30"}]
# Raw pricing for https://purebulk.com/products/zinc-oxide: [{'size': '250 grams', 'price': 'One-time purchase $12.50'}, {'size': '500 grams', 'price': 'One-time purchase $22.50'}, {'size': '1 kilogram', 'price': 'One-time purchase $40.50'}, {'size': '1.5 kilograms', 'price': 'One-time purchase $57.95'}]
# Cleaned pricing JSON for https://purebulk.com/products/zinc-oxide: [{"size": "250 grams", "price": "$12.50"}, {"size": "500 grams", "price": "$22.50"}, {"size": "1 kilogram", "price": "$40.50"}, {"size": "1.5 kilograms", "price": "$57.95"}]
# Raw pricing for https://purebulk.com/products/zinc-sulfate-monohydrate: [{'size': '100 grams', 'price': 'One-time purchase $8.50'}, {'size': '250 grams', 'price': 'One-time purchase $18.25'}, {'size': '500 grams', 'price': 'One-time purchase $32.95'}, {'size': '1 kilogram', 'price': 'One-time purchase $59.50'}, {'size': '1.5 kilograms', 'price': 'One-time purchase $84.95'}]
# Cleaned pricing JSON for https://purebulk.com/products/zinc-sulfate-monohydrate: [{"size": "100 grams", "price": "$8.50"}, {"size": "250 grams", "price": "$18.25"}, {"size": "500 grams", "price": "$32.95"}, {"size": "1 kilogram", "price": "$59.50"}, {"size": "1.5 kilograms", "price": "$84.95"}]
